# %% [markdown]
# # Gradient Boosting with XGBoost

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['retina']  # or svg
# %matplotlib inline

plt.rcParams['figure.figsize'] = (9, 6)
sns.set(context='notebook', style='whitegrid', font_scale=1.2)

from sklearn.datasets import fetch_california_housing
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
import xgboost as xgb

# %% [markdown]
# # Conceptual Overview & Hyperparameter Tuning
#
# **Goals**:
# 1. Introduce the basic mathematical framework behind gradient boosted trees and the model's key hyperparameters
# 2. Discuss typical use cases for gradient boosting and some pros and cons
# 3. Illustrate examples of the xgboost package, including selecting/tuning hyperparameters

# %% [markdown]
# ## Mathematical Framework
#
# Let's start by briefly returning to random forests. With the RF algorithm, we start with a very low bias but high variance **strong learner**, and reduce its variance by averaging across many relatively uncorrelated copies. Recall that we get these copies by injecting randomness into each base tree in the forest ensemble (taking bootstrapped samples of the training data, subsampling the feature columns for each tree split). The end result is a model that overfits less than a single decision tree. See the diagram from [KDnuggets](https://www.kdnuggets.com/2017/10/random-forests-explained.html) below.
#
# ![](images/RFDiagram.jpg)

# %% [markdown]
# **Boosting models** are a flipped version of this paradigm. Instead of a strong learner, we start with a high bias but low variance **weak learner** and reduce its bias by training models that iteratively correct for the mistakes made by previous models. Building a sort of tower of weak models in this fashion makes for a strong ensemble that doesn't underfit, and the low variance of each base model helps insulate the ensemble from overfitting.
#
# An especially powerful variety of boosting in modern ML is **gradient boosted trees**, which we'll focus on. Our base learner is a simple decision tree with relatively small depth / few decision splits. The most intuitive problem setting to start with here is regression, with the usual sum of the squared errors (SSE) as the loss function we aim to minimize for data $X, y$. In each step of model building, we fit a base learner tree to the residuals of the current model's training predictions, adding it to the ensemble and gradually decreasing our training error. We will build a final model by adding the results of these trees together.
#
# **We will walk through the regression mathematical framework.** Classification follows directly from this structure, but the math is a just slightly less straight forward.

# %% [markdown]
# #### Steps
#
# * We'll train $M$ base learner decision trees with max depth $d$, step by step, adding each to our overall model. *Note: $M$ and $d$ here are hyperparameters for the model.*
# * Each base tree model $f_m$ (little $f$) is fit using our data $X$, but **the target values are the residuals**, $y - F_{m-1}(X)$, where $F_{m-1}(X)$ (big $F$) is our overall model at that time step (sum of previous trees and initialization).
# * We initialize our model with the best constant prediction, $F_0 = f_0 = \mathbb{E}(y) = \texttt{mean}(y)$. This is a singled leafed tree which predicts $\texttt{mean}(y)$ for every input.

# %% [markdown]
# #### As an algorithm:
#
# 1. Set $F_0 = f_0 = \texttt{mean}(y)$
# 2. For $m = 1,\dots ,M$:
#     1. Set $F_{m-1}(X) = \displaystyle\sum_{j=0}^{m-1}f_j(X)$
#     2. Fit max depth $d$ tree $f_m$ with features $X$, target $y - F_{m-1}(X)$
#     3. So, $F_m(X) = F_{m-1}(X) + f_m(X)$, (for the next step).
#
# Obtain final model: $F(X) = f_0 + f_1(X) + \cdots + f_M(X)$
#
# ![](images/RegressDiagram.png)
#
# Not too complicated! But hold on, where does the *gradient* part of the name come in? And would we be able to adapt this model to a classification problem? As it turns out, the answer to both questions is the same.

# %% [markdown]
# #### Generalizing GBM to Differentiable Loss Functions
#
# The **gradient** bit is closely related to the gradient descent algorithm that we know and love. It's also where the real power of the GBM framework becomes apparent. With the more general version of the algorithm that we'll see below, we can simply plug in a differentiable loss function and get an appropriate model.
#
# To understand the general approach, consider the prediction values $F(X)$ that approximate the target $y$ for an arbitrary model $F$. Without putting any constraints on the function $F$, we could choose a differentiable loss function $L(y, F(X))$ and define the model that minimizes it:
#
# $$F_* = \underset{F}{\text{argmin }} L(y, F(X))$$

# %% [markdown]
# But since our loss function $L$ is differentiable, we can solve this problem by using iterative gradient descent to find a minimum. So, at each time step $t$, we define model update:
#
# $$F_{t}(X) = F_{t-1}(X) - \eta\nabla L(y, F_{t-1}(X))$$
#
# In other words, at each time step, we take the most recent estimations $F_{t-1}(X)$, and "move" them down ($-$) in the direction ($\nabla$) where the loss function $L(y, F_{t-1}(X))$ decreases the fastest. Each of these incremental movements will be a factor $\eta$ of the steepness of our direction $\nabla$. *Note: This $\eta$ is the "learning rate", a tool to help avoid overfitting.*

# %% [markdown]
# In the case of gradient boosting trees, we replaced timesteps $t$ with boosting steps $m$, and instead of using the pure gradient $\nabla L(y, F_{t-1}(X))$, we use a *model of the gradient* at each step with a regression tree $f_{m}$, fit on $X$ as features and the negative gradients $-\nabla L(y, F_{m-1}(X))$ as targets *(when we use MSE as our loss function, solving this gradient *equates* to calculating $y - F_{m-1}(x)$, which we saw above).*

# %% [markdown]
# Doing this, we can modify the "gradient descent" update rule so that it becomes:
#
# $$F_{m}(X) = F_{m-1}(X) + \eta f_{m}(X)$$

# %% [markdown]
# This looks exactly like the algorithm we used for regression boosting, just with a learning rate added to help correct for overfitting!
#
# 1. Choose loss function $L(y, F(y))$ *(e.g., for classification, we use the [softmax loss](https://www.kdnuggets.com/2016/07/softmax-regression-related-logistic-regression.html) function for $L$)*
# 2. Initialize with best constant prediction, $F_0 = f_0 = \texttt{mean}(y)$
# 2. For $m = 1,\dots, M$:
#     1. Calculate the (negative) gradients between the last full model and the target $r_{m-1} = -\nabla L(y, F_{m-1}(X))$
#     2. Fit max depth $d$ tree $f_m$ with features $X$, target $r_{m-1}$
#     3. Update $F_m(X) = F_{m-1}(X) + f_m(X)$
#
# Obtain final model: $F(X) = f_0 + f_1(X) + \dots + f_M(X)$
#
# And that's that.
#
# For a more detailed discussion on this, check out [explainable.ai](https://explained.ai/gradient-boosting/)'s post.

# %% [markdown]
# ### Pros and Cons of GBMs

# %% [markdown]
# Boosted tree models are often the gold standard for tabular data in modern machine learning. They are well-equipped to model complex ground-truth functions without overfitting, adapt to your loss function of choice, and scale well to large datasets. They tend to do quite well with messy data: tree methods handle missing values naturally and can filter out the least useful input variables based on feature selection for splitting. That said, they are usually more sensitive to hyperparameter choice than random forests and can be a bit tricky and time-consuming to tune. They also lack the explicit interpretability of simpler models like linear/logistic regression.
#
# In short, GBMs are a powerful tool to apply to a wide range of datasets (in terms of loss objective, size, variable types, and messiness). They are probably the closest thing to a catch-all and out-of-the-box modeling approach that currently exists. In a use case where you have at least a reasonable amount of data, want an optimally predictive model, can sacrifice some interpretability, and have the time/resources to tune multiple hyperparameters, you should definitely try a GBM model.
#
# ![](images/xgbcalm.png)
#
# **Summary**
#
# **Pros**:
#
# * Adaptable to wide range of problem settings (regression, classification, unusual or custom loss functions)
# * Potential to be highly expressive (model compex, non-linear relationships)...
# * But still flexible enough to accomodate complexity constraints/regularization
#
# *General tree benefits:*
#
# * Feature scale invariant / natural handling of heterogenous features
# * Automatic handling of missing/NA values
# * Automatic feature interaction
# * Robust to input outliers and unhelpful input features (automatic feature selection)
# * Scales well to large datasets
#
# **Cons**:
#
# * Many hyperparameters to tune for full power -- can be time-consuming and cause overfitting if not well-validated
# * Lack clear/clean interpretability
# * Tree methods struggle with extrapolation (can perform poorly on feature values outside of training range)
# * Can struggle with handling categorical variables (especially if large # of categories)

# %% [markdown]
# ### Hands on GBMs and parameter tuning
#
# Now that we've covered some of the theory behind GBMS and their pros and cons, let's turn to a concrete example of training one. We'll use [xgboost](https://github.com/dmlc/xgboost) (extreme gradient boosting), currently the most popular python package when it comes to training production-level boosting models.
#
# Another popular option is Microsoft's [lightgbm](https://github.com/Microsoft/LightGBM) package, which is  faster and sometimes more accurate than xgboost, but typically harder to tune and closer to bleeding edge as software. Sci-kit learn does have an easier to use [gbm implementation](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html), but it's less efficient and less powerful.
#
# Xgboost makes some adjustments to the algorithm described above and introduces a number of powerful efficiencies that allow the package to scale well. [This post](https://medium.com/@Synced/tree-boosting-with-xgboost-why-does-xgboost-win-every-machine-learning-competition-ca8034c0b283) is a good overview comparison of classic gradient boosting and xgboost, and the [xgboost paper](https://arxiv.org/pdf/1603.02754.pdf) digs into methodology and implementation details.
#
# For this example we'll use the California housing dataset that we've seen before (regression on housing prices). We'll first look at a couple of benchmarks, then step through the process of tuning an xgboost model and see what it can do. The process would be essentially the same for a classification problem (part of what makes boosting so great), which we'll see in a quick example at the end on the Wisconsin breast cancer dataset.

# %%
data = fetch_california_housing(as_frame=True)

# %%
X = data.data
y = data.target

# %%
X.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

#Split data into 3: 60% train, 20% validation, 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2018)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2019)

#Evaluate models with Root Mean Squared Error
def rmse(actuals, preds):
    return np.sqrt(((actuals - preds) ** 2).mean())

# %% [markdown]
# Linear regression benchmark:

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
rmse(lr.predict(X_test), y_test)
# Out:
# 0.7308026104606054

# %% [markdown]
# Random forest benchmark:

# %%
rf = RandomForestRegressor(n_estimators = 100, max_features = 3, n_jobs=-1)
rf.fit(X_train,y_train)
rmse(rf.predict(X_test), y_test)
# Out:
# 0.5078890542854982

# %% [markdown]
# **Xgboost Tuning**
#
# Now that we've set a solid baseline, let's turn to xgboost. Most of the parameters we'll use here should be familiar from the first section of this notebook or similar to what we've seen for random forests, with the exception of *learning rate*.
#
# **n_estimators**: number of base learner trees
# **max_depth**: max depth per base tree (typical values are 3-12)
# **learning_rate**: shrinkage factor applied to each base tree update
# **subsample**: row subsampling rate (similar to RF)
# **min_child_weight**: roughly the minimum allowable child samples for a tree split to occur
# **colsample_bytree**: feature subsampling rate (similar to RF)
#
# The use of a learning rate/shrinkage factor is a form of regularization that can greatly reduce overfitting. It typically trades off with the n_estimators and depth parameters (raising these add complexity) -- lower learning rate  usually wants higher n_estimators, higher max depth usually wants lower learning rate etc. The two subsampling parameters and min_child_weight are also forms of regularization. These types of tradeoffs are part of why it typically works better to follow a manual tuning procedure than to try a massive grid search across different parameter combinations. That simply doesn't scale well to large datasets.
#
# Instead of trying to pick n_estimators by hand or do an intensive grid search, we'll use the **early stopping** technique as a massive time saver. This means that we track our validation error at each update step in the training process, and halt training once validation error hasn't improved in some number of **early_stopping_rounds**. This way, we can set n_estimators to a very large number and simply train until we land at a good stopping point for validation error.
#
# (One technical problem with early stopping is that n_estimators selection can overfit to the validation data. One reasonable solution is to combine early stopping with k-fold cross validation, and use the average n_estimators across k training rounds for training a new model).
#
# Here is our first xgboost example:

# %%
gbm = xgb.XGBRegressor( 
                       n_estimators=30000, #arbitrary large number
                       max_depth=3,
                       objective="reg:squarederror",
                       learning_rate=.1, 
                       subsample=1,
                       min_child_weight=1,
                       colsample_bytree=.8
                      )

eval_set=[(X_train,y_train),(X_val,y_val)] #tracking train/validation error as we go
fit_model = gbm.fit( 
                    X_train, y_train, 
                    eval_set=eval_set,
                    eval_metric='rmse',
                    early_stopping_rounds=20,
                    verbose=True #gives output log as below
                   )
# Out:
# [0]	validation_0-rmse:1.78671	validation_1-rmse:1.79240
# [1]	validation_0-rmse:1.64664	validation_1-rmse:1.65289
# [2]	validation_0-rmse:1.52197	validation_1-rmse:1.52868
# [3]	validation_0-rmse:1.42160	validation_1-rmse:1.42987
# [4]	validation_0-rmse:1.31967	validation_1-rmse:1.32964
# [5]	validation_0-rmse:1.23046	validation_1-rmse:1.24196
# [6]	validation_0-rmse:1.15942	validation_1-rmse:1.17105
# [7]	validation_0-rmse:1.08960	validation_1-rmse:1.10266
# [8]	validation_0-rmse:1.03870	validation_1-rmse:1.05154
# [9]	validation_0-rmse:0.98369	validation_1-rmse:0.99885
# [10]	validation_0-rmse:0.93956	validation_1-rmse:0.95470
# [11]	validation_0-rmse:0.89716	validation_1-rmse:0.91317
# [12]	validation_0-rmse:0.86540	validation_1-rmse:0.88178
# [13]	validation_0-rmse:0.83705	validation_1-rmse:0.85348
# [14]	validation_0-rmse:0.80778	validation_1-rmse:0.82579
# [15]	validation_0-rmse:0.78617	validation_1-rmse:0.80390
# [16]	validation_0-rmse:0.76449	validation_1-rmse:0.78228
# [17]	validation_0-rmse:0.74581	validation_1-rmse:0.76322
# [18]	validation_0-rmse:0.72901	validation_1-rmse:0.74722
# [19]	validation_0-rmse:0.71383	validation_1-rmse:0.73272
# [20]	validation_0-rmse:0.70117	validation_1-rmse:0.72006
# [21]	validation_0-rmse:0.68974	validation_1-rmse:0.70889
# [22]	validation_0-rmse:0.67826	validation_1-rmse:0.69729
# [23]	validation_0-rmse:0.66904	validation_1-rmse:0.68776
# [24]	validation_0-rmse:0.65861	validation_1-rmse:0.67806
# [25]	validation_0-rmse:0.65102	validation_1-rmse:0.67053
# [26]	validation_0-rmse:0.64326	validation_1-rmse:0.66247
# [27]	validation_0-rmse:0.63736	validation_1-rmse:0.65708
# [28]	validation_0-rmse:0.62811	validation_1-rmse:0.64786
# [29]	validation_0-rmse:0.62413	validation_1-rmse:0.64374
# [30]	validation_0-rmse:0.61961	validation_1-rmse:0.63954
# [31]	validation_0-rmse:0.61442	validation_1-rmse:0.63517
# [32]	validation_0-rmse:0.61020	validation_1-rmse:0.63068
# [33]	validation_0-rmse:0.60252	validation_1-rmse:0.62282
# [34]	validation_0-rmse:0.59886	validation_1-rmse:0.61882
# [35]	validation_0-rmse:0.59403	validation_1-rmse:0.61405
# [36]	validation_0-rmse:0.59142	validation_1-rmse:0.61177
# [37]	validation_0-rmse:0.58506	validation_1-rmse:0.60534
# [38]	validation_0-rmse:0.58305	validation_1-rmse:0.60352
# [39]	validation_0-rmse:0.57933	validation_1-rmse:0.59996
# [40]	validation_0-rmse:0.57446	validation_1-rmse:0.59493
# [41]	validation_0-rmse:0.56973	validation_1-rmse:0.58994
# [42]	validation_0-rmse:0.56822	validation_1-rmse:0.58874
# [43]	validation_0-rmse:0.56659	validation_1-rmse:0.58786
# [44]	validation_0-rmse:0.56485	validation_1-rmse:0.58633
# [45]	validation_0-rmse:0.56304	validation_1-rmse:0.58448
# [46]	validation_0-rmse:0.56101	validation_1-rmse:0.58278
# [47]	validation_0-rmse:0.55850	validation_1-rmse:0.58042
# [48]	validation_0-rmse:0.55605	validation_1-rmse:0.57799
# [49]	validation_0-rmse:0.55442	validation_1-rmse:0.57654
# [50]	validation_0-rmse:0.55321	validation_1-rmse:0.57608
# [51]	validation_0-rmse:0.54868	validation_1-rmse:0.57173
# [52]	validation_0-rmse:0.54756	validation_1-rmse:0.57064
# [53]	validation_0-rmse:0.54662	validation_1-rmse:0.56976
# [54]	validation_0-rmse:0.54485	validation_1-rmse:0.56807
# [55]	validation_0-rmse:0.54085	validation_1-rmse:0.56443
# [56]	validation_0-rmse:0.54002	validation_1-rmse:0.56408
# [57]	validation_0-rmse:0.53677	validation_1-rmse:0.56070
# [58]	validation_0-rmse:0.53574	validation_1-rmse:0.56001
# [59]	validation_0-rmse:0.53393	validation_1-rmse:0.55835
# [60]	validation_0-rmse:0.53110	validation_1-rmse:0.55636
# [61]	validation_0-rmse:0.53033	validation_1-rmse:0.55578
# [62]	validation_0-rmse:0.52927	validation_1-rmse:0.55480
# [63]	validation_0-rmse:0.52859	validation_1-rmse:0.55425
# [64]	validation_0-rmse:0.52754	validation_1-rmse:0.55366
# [65]	validation_0-rmse:0.52609	validation_1-rmse:0.55259
# [66]	validation_0-rmse:0.52389	validation_1-rmse:0.55043
# [67]	validation_0-rmse:0.52297	validation_1-rmse:0.54961
# [68]	validation_0-rmse:0.52251	validation_1-rmse:0.54950
# [69]	validation_0-rmse:0.52193	validation_1-rmse:0.54932
# [70]	validation_0-rmse:0.52037	validation_1-rmse:0.54801
# [71]	validation_0-rmse:0.51901	validation_1-rmse:0.54674
# [72]	validation_0-rmse:0.51833	validation_1-rmse:0.54631
# [73]	validation_0-rmse:0.51735	validation_1-rmse:0.54537
# [74]	validation_0-rmse:0.51656	validation_1-rmse:0.54468
# [75]	validation_0-rmse:0.51599	validation_1-rmse:0.54466
# [76]	validation_0-rmse:0.51519	validation_1-rmse:0.54409
# [77]	validation_0-rmse:0.51448	validation_1-rmse:0.54385
# [78]	validation_0-rmse:0.51395	validation_1-rmse:0.54365
# [79]	validation_0-rmse:0.51326	validation_1-rmse:0.54301
# [80]	validation_0-rmse:0.51208	validation_1-rmse:0.54192
# [81]	validation_0-rmse:0.51144	validation_1-rmse:0.54163
# [82]	validation_0-rmse:0.51086	validation_1-rmse:0.54137
# [83]	validation_0-rmse:0.51023	validation_1-rmse:0.54121
# [84]	validation_0-rmse:0.50982	validation_1-rmse:0.54074
# [85]	validation_0-rmse:0.50936	validation_1-rmse:0.54055
# [86]	validation_0-rmse:0.50884	validation_1-rmse:0.54009
# [87]	validation_0-rmse:0.50847	validation_1-rmse:0.53988
# [88]	validation_0-rmse:0.50788	validation_1-rmse:0.53965
# [89]	validation_0-rmse:0.50701	validation_1-rmse:0.53901
# [90]	validation_0-rmse:0.50615	validation_1-rmse:0.53833
# [91]	validation_0-rmse:0.50575	validation_1-rmse:0.53807
# [92]	validation_0-rmse:0.50548	validation_1-rmse:0.53785
# [93]	validation_0-rmse:0.50494	validation_1-rmse:0.53748
# [94]	validation_0-rmse:0.50315	validation_1-rmse:0.53575
# [95]	validation_0-rmse:0.50271	validation_1-rmse:0.53552
# [96]	validation_0-rmse:0.50182	validation_1-rmse:0.53494
# [97]	validation_0-rmse:0.50167	validation_1-rmse:0.53505
# [98]	validation_0-rmse:0.50132	validation_1-rmse:0.53522
# [99]	validation_0-rmse:0.50054	validation_1-rmse:0.53499
# [100]	validation_0-rmse:0.50024	validation_1-rmse:0.53468
# [101]	validation_0-rmse:0.49994	validation_1-rmse:0.53443
# [102]	validation_0-rmse:0.49892	validation_1-rmse:0.53371
# [103]	validation_0-rmse:0.49818	validation_1-rmse:0.53297
# [104]	validation_0-rmse:0.49786	validation_1-rmse:0.53283
# [105]	validation_0-rmse:0.49730	validation_1-rmse:0.53245
# [106]	validation_0-rmse:0.49569	validation_1-rmse:0.53113
# [107]	validation_0-rmse:0.49490	validation_1-rmse:0.53075
# [108]	validation_0-rmse:0.49403	validation_1-rmse:0.53000
# [109]	validation_0-rmse:0.49349	validation_1-rmse:0.52969
# [110]	validation_0-rmse:0.49304	validation_1-rmse:0.52953
# [111]	validation_0-rmse:0.49273	validation_1-rmse:0.52934
# [112]	validation_0-rmse:0.49211	validation_1-rmse:0.52925
# [113]	validation_0-rmse:0.49137	validation_1-rmse:0.52862
# [114]	validation_0-rmse:0.49066	validation_1-rmse:0.52827
# [115]	validation_0-rmse:0.49034	validation_1-rmse:0.52802
# [116]	validation_0-rmse:0.48996	validation_1-rmse:0.52788
# [117]	validation_0-rmse:0.48976	validation_1-rmse:0.52791
# [118]	validation_0-rmse:0.48863	validation_1-rmse:0.52681
# [119]	validation_0-rmse:0.48839	validation_1-rmse:0.52688
# [120]	validation_0-rmse:0.48798	validation_1-rmse:0.52673
# [121]	validation_0-rmse:0.48721	validation_1-rmse:0.52587
# [122]	validation_0-rmse:0.48686	validation_1-rmse:0.52588
# [123]	validation_0-rmse:0.48645	validation_1-rmse:0.52576
# [124]	validation_0-rmse:0.48579	validation_1-rmse:0.52519
# [125]	validation_0-rmse:0.48540	validation_1-rmse:0.52516
# [126]	validation_0-rmse:0.48497	validation_1-rmse:0.52524
# [127]	validation_0-rmse:0.48480	validation_1-rmse:0.52527
# [128]	validation_0-rmse:0.48462	validation_1-rmse:0.52526
# [129]	validation_0-rmse:0.48452	validation_1-rmse:0.52532
# [130]	validation_0-rmse:0.48391	validation_1-rmse:0.52482
# [131]	validation_0-rmse:0.48374	validation_1-rmse:0.52486
# [132]	validation_0-rmse:0.48334	validation_1-rmse:0.52470
# [133]	validation_0-rmse:0.48282	validation_1-rmse:0.52445
# [134]	validation_0-rmse:0.48242	validation_1-rmse:0.52424
# [135]	validation_0-rmse:0.48206	validation_1-rmse:0.52377
# [136]	validation_0-rmse:0.48148	validation_1-rmse:0.52350
# [137]	validation_0-rmse:0.48129	validation_1-rmse:0.52332
# [138]	validation_0-rmse:0.48096	validation_1-rmse:0.52327
# [139]	validation_0-rmse:0.48036	validation_1-rmse:0.52304
# [140]	validation_0-rmse:0.47989	validation_1-rmse:0.52285
# [141]	validation_0-rmse:0.47973	validation_1-rmse:0.52281
# [142]	validation_0-rmse:0.47957	validation_1-rmse:0.52290
# [143]	validation_0-rmse:0.47910	validation_1-rmse:0.52268
# [144]	validation_0-rmse:0.47860	validation_1-rmse:0.52236
# [145]	validation_0-rmse:0.47824	validation_1-rmse:0.52219
# [146]	validation_0-rmse:0.47781	validation_1-rmse:0.52192
# [147]	validation_0-rmse:0.47752	validation_1-rmse:0.52168
# [148]	validation_0-rmse:0.47712	validation_1-rmse:0.52158
# [149]	validation_0-rmse:0.47680	validation_1-rmse:0.52142
# [150]	validation_0-rmse:0.47661	validation_1-rmse:0.52149
# [151]	validation_0-rmse:0.47615	validation_1-rmse:0.52119
# [152]	validation_0-rmse:0.47583	validation_1-rmse:0.52112
# [153]	validation_0-rmse:0.47541	validation_1-rmse:0.52094
# [154]	validation_0-rmse:0.47455	validation_1-rmse:0.51994
# [155]	validation_0-rmse:0.47422	validation_1-rmse:0.51980
# [156]	validation_0-rmse:0.47396	validation_1-rmse:0.51972
# [157]	validation_0-rmse:0.47382	validation_1-rmse:0.51974
# [158]	validation_0-rmse:0.47370	validation_1-rmse:0.51969
# [159]	validation_0-rmse:0.47328	validation_1-rmse:0.51944
# [160]	validation_0-rmse:0.47310	validation_1-rmse:0.51949
# [161]	validation_0-rmse:0.47243	validation_1-rmse:0.51877
# [162]	validation_0-rmse:0.47174	validation_1-rmse:0.51839
# [163]	validation_0-rmse:0.47141	validation_1-rmse:0.51827
# [164]	validation_0-rmse:0.47127	validation_1-rmse:0.51824
# [165]	validation_0-rmse:0.47092	validation_1-rmse:0.51801
# [166]	validation_0-rmse:0.47084	validation_1-rmse:0.51795
# [167]	validation_0-rmse:0.47055	validation_1-rmse:0.51784
# [168]	validation_0-rmse:0.47042	validation_1-rmse:0.51788
# [169]	validation_0-rmse:0.47012	validation_1-rmse:0.51779
# [170]	validation_0-rmse:0.46989	validation_1-rmse:0.51771
# [171]	validation_0-rmse:0.46930	validation_1-rmse:0.51699
# [172]	validation_0-rmse:0.46903	validation_1-rmse:0.51698
# [173]	validation_0-rmse:0.46875	validation_1-rmse:0.51697
# [174]	validation_0-rmse:0.46770	validation_1-rmse:0.51582
# [175]	validation_0-rmse:0.46759	validation_1-rmse:0.51578
# [176]	validation_0-rmse:0.46700	validation_1-rmse:0.51524
# [177]	validation_0-rmse:0.46666	validation_1-rmse:0.51502
# [178]	validation_0-rmse:0.46652	validation_1-rmse:0.51492
# [179]	validation_0-rmse:0.46609	validation_1-rmse:0.51475
# [180]	validation_0-rmse:0.46594	validation_1-rmse:0.51478
# [181]	validation_0-rmse:0.46580	validation_1-rmse:0.51486
# [182]	validation_0-rmse:0.46570	validation_1-rmse:0.51486
# [183]	validation_0-rmse:0.46541	validation_1-rmse:0.51479
# [184]	validation_0-rmse:0.46517	validation_1-rmse:0.51453
# [185]	validation_0-rmse:0.46492	validation_1-rmse:0.51445
# [186]	validation_0-rmse:0.46471	validation_1-rmse:0.51430
# [187]	validation_0-rmse:0.46444	validation_1-rmse:0.51418
# [188]	validation_0-rmse:0.46423	validation_1-rmse:0.51406
# [189]	validation_0-rmse:0.46406	validation_1-rmse:0.51397
# [190]	validation_0-rmse:0.46382	validation_1-rmse:0.51384
# [191]	validation_0-rmse:0.46370	validation_1-rmse:0.51390
# [192]	validation_0-rmse:0.46343	validation_1-rmse:0.51368
# [193]	validation_0-rmse:0.46323	validation_1-rmse:0.51363
# [194]	validation_0-rmse:0.46314	validation_1-rmse:0.51369
# [195]	validation_0-rmse:0.46290	validation_1-rmse:0.51351
# [196]	validation_0-rmse:0.46249	validation_1-rmse:0.51328
# [197]	validation_0-rmse:0.46232	validation_1-rmse:0.51331
# [198]	validation_0-rmse:0.46212	validation_1-rmse:0.51333
# [199]	validation_0-rmse:0.46159	validation_1-rmse:0.51306
# [200]	validation_0-rmse:0.46120	validation_1-rmse:0.51263
# [201]	validation_0-rmse:0.46092	validation_1-rmse:0.51246
# [202]	validation_0-rmse:0.46064	validation_1-rmse:0.51244
# [203]	validation_0-rmse:0.46036	validation_1-rmse:0.51228
# [204]	validation_0-rmse:0.46021	validation_1-rmse:0.51239
# [205]	validation_0-rmse:0.45997	validation_1-rmse:0.51234
# [206]	validation_0-rmse:0.45986	validation_1-rmse:0.51230
# [207]	validation_0-rmse:0.45971	validation_1-rmse:0.51223
# [208]	validation_0-rmse:0.45948	validation_1-rmse:0.51206
# [209]	validation_0-rmse:0.45921	validation_1-rmse:0.51203
# [210]	validation_0-rmse:0.45903	validation_1-rmse:0.51208
# [211]	validation_0-rmse:0.45880	validation_1-rmse:0.51193
# [212]	validation_0-rmse:0.45807	validation_1-rmse:0.51127
# [213]	validation_0-rmse:0.45768	validation_1-rmse:0.51084
# [214]	validation_0-rmse:0.45720	validation_1-rmse:0.51047
# [215]	validation_0-rmse:0.45698	validation_1-rmse:0.51037
# [216]	validation_0-rmse:0.45665	validation_1-rmse:0.51031
# [217]	validation_0-rmse:0.45630	validation_1-rmse:0.51017
# [218]	validation_0-rmse:0.45560	validation_1-rmse:0.50947
# [219]	validation_0-rmse:0.45541	validation_1-rmse:0.50948
# [220]	validation_0-rmse:0.45520	validation_1-rmse:0.50945
# [221]	validation_0-rmse:0.45504	validation_1-rmse:0.50940
# [222]	validation_0-rmse:0.45448	validation_1-rmse:0.50885
# [223]	validation_0-rmse:0.45421	validation_1-rmse:0.50868
# [224]	validation_0-rmse:0.45398	validation_1-rmse:0.50859
# [225]	validation_0-rmse:0.45388	validation_1-rmse:0.50868
# [226]	validation_0-rmse:0.45375	validation_1-rmse:0.50865
# [227]	validation_0-rmse:0.45368	validation_1-rmse:0.50867
# [228]	validation_0-rmse:0.45333	validation_1-rmse:0.50852
# [229]	validation_0-rmse:0.45320	validation_1-rmse:0.50848
# [230]	validation_0-rmse:0.45302	validation_1-rmse:0.50838
# [231]	validation_0-rmse:0.45284	validation_1-rmse:0.50818
# [232]	validation_0-rmse:0.45258	validation_1-rmse:0.50786
# [233]	validation_0-rmse:0.45229	validation_1-rmse:0.50784
# [234]	validation_0-rmse:0.45214	validation_1-rmse:0.50768
# [235]	validation_0-rmse:0.45206	validation_1-rmse:0.50766
# [236]	validation_0-rmse:0.45188	validation_1-rmse:0.50765
# [237]	validation_0-rmse:0.45160	validation_1-rmse:0.50750
# [238]	validation_0-rmse:0.45149	validation_1-rmse:0.50749
# [239]	validation_0-rmse:0.45129	validation_1-rmse:0.50738
# [240]	validation_0-rmse:0.45085	validation_1-rmse:0.50676
# [241]	validation_0-rmse:0.45061	validation_1-rmse:0.50664
# [242]	validation_0-rmse:0.45029	validation_1-rmse:0.50660
# [243]	validation_0-rmse:0.45003	validation_1-rmse:0.50642
# [244]	validation_0-rmse:0.44977	validation_1-rmse:0.50627
# [245]	validation_0-rmse:0.44948	validation_1-rmse:0.50613
# [246]	validation_0-rmse:0.44933	validation_1-rmse:0.50604
# [247]	validation_0-rmse:0.44913	validation_1-rmse:0.50600
# [248]	validation_0-rmse:0.44885	validation_1-rmse:0.50623
# [249]	validation_0-rmse:0.44868	validation_1-rmse:0.50619
# [250]	validation_0-rmse:0.44839	validation_1-rmse:0.50610
# [251]	validation_0-rmse:0.44780	validation_1-rmse:0.50550
# [252]	validation_0-rmse:0.44771	validation_1-rmse:0.50549
# [253]	validation_0-rmse:0.44739	validation_1-rmse:0.50518
# [254]	validation_0-rmse:0.44722	validation_1-rmse:0.50516
# [255]	validation_0-rmse:0.44682	validation_1-rmse:0.50491
# [256]	validation_0-rmse:0.44670	validation_1-rmse:0.50496
# [257]	validation_0-rmse:0.44656	validation_1-rmse:0.50498
# [258]	validation_0-rmse:0.44628	validation_1-rmse:0.50492
# [259]	validation_0-rmse:0.44620	validation_1-rmse:0.50492
# [260]	validation_0-rmse:0.44613	validation_1-rmse:0.50491
# [261]	validation_0-rmse:0.44601	validation_1-rmse:0.50487
# [262]	validation_0-rmse:0.44594	validation_1-rmse:0.50485
# [263]	validation_0-rmse:0.44576	validation_1-rmse:0.50490
# [264]	validation_0-rmse:0.44518	validation_1-rmse:0.50465
# [265]	validation_0-rmse:0.44496	validation_1-rmse:0.50464
# [266]	validation_0-rmse:0.44464	validation_1-rmse:0.50466
# [267]	validation_0-rmse:0.44430	validation_1-rmse:0.50436
# [268]	validation_0-rmse:0.44412	validation_1-rmse:0.50431
# [269]	validation_0-rmse:0.44400	validation_1-rmse:0.50428
# [270]	validation_0-rmse:0.44389	validation_1-rmse:0.50421
# [271]	validation_0-rmse:0.44349	validation_1-rmse:0.50386
# [272]	validation_0-rmse:0.44322	validation_1-rmse:0.50379
# [273]	validation_0-rmse:0.44288	validation_1-rmse:0.50342
# [274]	validation_0-rmse:0.44275	validation_1-rmse:0.50345
# [275]	validation_0-rmse:0.44248	validation_1-rmse:0.50325
# [276]	validation_0-rmse:0.44220	validation_1-rmse:0.50303
# [277]	validation_0-rmse:0.44153	validation_1-rmse:0.50250
# [278]	validation_0-rmse:0.44136	validation_1-rmse:0.50240
# [279]	validation_0-rmse:0.44126	validation_1-rmse:0.50242
# [280]	validation_0-rmse:0.44107	validation_1-rmse:0.50229
# [281]	validation_0-rmse:0.44096	validation_1-rmse:0.50222
# [282]	validation_0-rmse:0.44082	validation_1-rmse:0.50215
# [283]	validation_0-rmse:0.44051	validation_1-rmse:0.50203
# [284]	validation_0-rmse:0.44024	validation_1-rmse:0.50200
# [285]	validation_0-rmse:0.44011	validation_1-rmse:0.50200
# [286]	validation_0-rmse:0.43989	validation_1-rmse:0.50197
# [287]	validation_0-rmse:0.43969	validation_1-rmse:0.50194
# [288]	validation_0-rmse:0.43934	validation_1-rmse:0.50171
# [289]	validation_0-rmse:0.43925	validation_1-rmse:0.50176
# [290]	validation_0-rmse:0.43901	validation_1-rmse:0.50169
# [291]	validation_0-rmse:0.43879	validation_1-rmse:0.50153
# [292]	validation_0-rmse:0.43851	validation_1-rmse:0.50119
# [293]	validation_0-rmse:0.43841	validation_1-rmse:0.50121
# [294]	validation_0-rmse:0.43833	validation_1-rmse:0.50117
# [295]	validation_0-rmse:0.43824	validation_1-rmse:0.50120
# [296]	validation_0-rmse:0.43814	validation_1-rmse:0.50120
# [297]	validation_0-rmse:0.43804	validation_1-rmse:0.50122
# [298]	validation_0-rmse:0.43786	validation_1-rmse:0.50118
# [299]	validation_0-rmse:0.43762	validation_1-rmse:0.50112
# [300]	validation_0-rmse:0.43741	validation_1-rmse:0.50093
# [301]	validation_0-rmse:0.43714	validation_1-rmse:0.50098
# [302]	validation_0-rmse:0.43704	validation_1-rmse:0.50090
# [303]	validation_0-rmse:0.43687	validation_1-rmse:0.50091
# [304]	validation_0-rmse:0.43672	validation_1-rmse:0.50085
# [305]	validation_0-rmse:0.43664	validation_1-rmse:0.50086
# [306]	validation_0-rmse:0.43632	validation_1-rmse:0.50068
# [307]	validation_0-rmse:0.43589	validation_1-rmse:0.50043
# [308]	validation_0-rmse:0.43565	validation_1-rmse:0.50045
# [309]	validation_0-rmse:0.43554	validation_1-rmse:0.50037
# [310]	validation_0-rmse:0.43535	validation_1-rmse:0.50045
# [311]	validation_0-rmse:0.43509	validation_1-rmse:0.50030
# [312]	validation_0-rmse:0.43486	validation_1-rmse:0.50017
# [313]	validation_0-rmse:0.43474	validation_1-rmse:0.50012
# [314]	validation_0-rmse:0.43443	validation_1-rmse:0.49989
# [315]	validation_0-rmse:0.43405	validation_1-rmse:0.49960
# [316]	validation_0-rmse:0.43391	validation_1-rmse:0.49950
# [317]	validation_0-rmse:0.43380	validation_1-rmse:0.49948
# [318]	validation_0-rmse:0.43374	validation_1-rmse:0.49947
# [319]	validation_0-rmse:0.43366	validation_1-rmse:0.49948
# [320]	validation_0-rmse:0.43343	validation_1-rmse:0.49948
# [321]	validation_0-rmse:0.43326	validation_1-rmse:0.49953
# [322]	validation_0-rmse:0.43306	validation_1-rmse:0.49950
# [323]	validation_0-rmse:0.43286	validation_1-rmse:0.49936
# [324]	validation_0-rmse:0.43275	validation_1-rmse:0.49945
# [325]	validation_0-rmse:0.43259	validation_1-rmse:0.49941
# [326]	validation_0-rmse:0.43243	validation_1-rmse:0.49922
# [327]	validation_0-rmse:0.43223	validation_1-rmse:0.49918
# [328]	validation_0-rmse:0.43216	validation_1-rmse:0.49922
# [329]	validation_0-rmse:0.43197	validation_1-rmse:0.49908
# [330]	validation_0-rmse:0.43189	validation_1-rmse:0.49906
# [331]	validation_0-rmse:0.43183	validation_1-rmse:0.49902
# [332]	validation_0-rmse:0.43167	validation_1-rmse:0.49891
# [333]	validation_0-rmse:0.43140	validation_1-rmse:0.49869
# [334]	validation_0-rmse:0.43123	validation_1-rmse:0.49868
# [335]	validation_0-rmse:0.43109	validation_1-rmse:0.49863
# [336]	validation_0-rmse:0.43096	validation_1-rmse:0.49866
# [337]	validation_0-rmse:0.43087	validation_1-rmse:0.49866
# [338]	validation_0-rmse:0.43066	validation_1-rmse:0.49845
# [339]	validation_0-rmse:0.43006	validation_1-rmse:0.49802
# [340]	validation_0-rmse:0.42993	validation_1-rmse:0.49798
# [341]	validation_0-rmse:0.42981	validation_1-rmse:0.49794
# [342]	validation_0-rmse:0.42971	validation_1-rmse:0.49787
# [343]	validation_0-rmse:0.42951	validation_1-rmse:0.49772
# [344]	validation_0-rmse:0.42920	validation_1-rmse:0.49759
# [345]	validation_0-rmse:0.42891	validation_1-rmse:0.49739
# [346]	validation_0-rmse:0.42883	validation_1-rmse:0.49744
# [347]	validation_0-rmse:0.42867	validation_1-rmse:0.49731
# [348]	validation_0-rmse:0.42860	validation_1-rmse:0.49732
# [349]	validation_0-rmse:0.42836	validation_1-rmse:0.49741
# [350]	validation_0-rmse:0.42823	validation_1-rmse:0.49740
# [351]	validation_0-rmse:0.42816	validation_1-rmse:0.49737
# [352]	validation_0-rmse:0.42794	validation_1-rmse:0.49721
# [353]	validation_0-rmse:0.42782	validation_1-rmse:0.49719
# [354]	validation_0-rmse:0.42756	validation_1-rmse:0.49699
# [355]	validation_0-rmse:0.42740	validation_1-rmse:0.49698
# [356]	validation_0-rmse:0.42720	validation_1-rmse:0.49683
# [357]	validation_0-rmse:0.42669	validation_1-rmse:0.49644
# [358]	validation_0-rmse:0.42646	validation_1-rmse:0.49639
# [359]	validation_0-rmse:0.42628	validation_1-rmse:0.49632
# [360]	validation_0-rmse:0.42622	validation_1-rmse:0.49635
# [361]	validation_0-rmse:0.42617	validation_1-rmse:0.49640
# [362]	validation_0-rmse:0.42593	validation_1-rmse:0.49628
# [363]	validation_0-rmse:0.42578	validation_1-rmse:0.49629
# [364]	validation_0-rmse:0.42573	validation_1-rmse:0.49636
# [365]	validation_0-rmse:0.42570	validation_1-rmse:0.49641
# [366]	validation_0-rmse:0.42524	validation_1-rmse:0.49627
# [367]	validation_0-rmse:0.42499	validation_1-rmse:0.49618
# [368]	validation_0-rmse:0.42468	validation_1-rmse:0.49617
# [369]	validation_0-rmse:0.42449	validation_1-rmse:0.49600
# [370]	validation_0-rmse:0.42440	validation_1-rmse:0.49600
# [371]	validation_0-rmse:0.42423	validation_1-rmse:0.49583
# [372]	validation_0-rmse:0.42409	validation_1-rmse:0.49587
# [373]	validation_0-rmse:0.42387	validation_1-rmse:0.49571
# [374]	validation_0-rmse:0.42373	validation_1-rmse:0.49557
# [375]	validation_0-rmse:0.42329	validation_1-rmse:0.49522
# [376]	validation_0-rmse:0.42314	validation_1-rmse:0.49520
# [377]	validation_0-rmse:0.42296	validation_1-rmse:0.49516
# [378]	validation_0-rmse:0.42280	validation_1-rmse:0.49501
# [379]	validation_0-rmse:0.42265	validation_1-rmse:0.49499
# [380]	validation_0-rmse:0.42194	validation_1-rmse:0.49438
# [381]	validation_0-rmse:0.42180	validation_1-rmse:0.49440
# [382]	validation_0-rmse:0.42167	validation_1-rmse:0.49438
# [383]	validation_0-rmse:0.42155	validation_1-rmse:0.49429
# [384]	validation_0-rmse:0.42149	validation_1-rmse:0.49434
# [385]	validation_0-rmse:0.42136	validation_1-rmse:0.49422
# [386]	validation_0-rmse:0.42100	validation_1-rmse:0.49423
# [387]	validation_0-rmse:0.42080	validation_1-rmse:0.49425
# [388]	validation_0-rmse:0.42074	validation_1-rmse:0.49422
# [389]	validation_0-rmse:0.42066	validation_1-rmse:0.49419
# [390]	validation_0-rmse:0.42051	validation_1-rmse:0.49410
# [391]	validation_0-rmse:0.42036	validation_1-rmse:0.49409
# [392]	validation_0-rmse:0.42009	validation_1-rmse:0.49398
# [393]	validation_0-rmse:0.41998	validation_1-rmse:0.49392
# [394]	validation_0-rmse:0.41985	validation_1-rmse:0.49393
# [395]	validation_0-rmse:0.41969	validation_1-rmse:0.49392
# [396]	validation_0-rmse:0.41954	validation_1-rmse:0.49395
# [397]	validation_0-rmse:0.41937	validation_1-rmse:0.49394
# [398]	validation_0-rmse:0.41927	validation_1-rmse:0.49384
# [399]	validation_0-rmse:0.41909	validation_1-rmse:0.49382
# [400]	validation_0-rmse:0.41895	validation_1-rmse:0.49378
# [401]	validation_0-rmse:0.41881	validation_1-rmse:0.49377
# [402]	validation_0-rmse:0.41867	validation_1-rmse:0.49373
# [403]	validation_0-rmse:0.41850	validation_1-rmse:0.49376
# [404]	validation_0-rmse:0.41832	validation_1-rmse:0.49359
# [405]	validation_0-rmse:0.41819	validation_1-rmse:0.49363
# [406]	validation_0-rmse:0.41797	validation_1-rmse:0.49356
# [407]	validation_0-rmse:0.41766	validation_1-rmse:0.49327
# [408]	validation_0-rmse:0.41756	validation_1-rmse:0.49324
# [409]	validation_0-rmse:0.41743	validation_1-rmse:0.49323
# [410]	validation_0-rmse:0.41731	validation_1-rmse:0.49321
# [411]	validation_0-rmse:0.41720	validation_1-rmse:0.49321
# [412]	validation_0-rmse:0.41700	validation_1-rmse:0.49316
# [413]	validation_0-rmse:0.41685	validation_1-rmse:0.49317
# [414]	validation_0-rmse:0.41670	validation_1-rmse:0.49324
# [415]	validation_0-rmse:0.41657	validation_1-rmse:0.49328
# [416]	validation_0-rmse:0.41651	validation_1-rmse:0.49326
# [417]	validation_0-rmse:0.41639	validation_1-rmse:0.49311
# [418]	validation_0-rmse:0.41631	validation_1-rmse:0.49309
# [419]	validation_0-rmse:0.41619	validation_1-rmse:0.49314
# [420]	validation_0-rmse:0.41604	validation_1-rmse:0.49322
# [421]	validation_0-rmse:0.41591	validation_1-rmse:0.49314
# [422]	validation_0-rmse:0.41576	validation_1-rmse:0.49316
# [423]	validation_0-rmse:0.41562	validation_1-rmse:0.49312
# [424]	validation_0-rmse:0.41531	validation_1-rmse:0.49293
# [425]	validation_0-rmse:0.41508	validation_1-rmse:0.49284
# [426]	validation_0-rmse:0.41484	validation_1-rmse:0.49273
# [427]	validation_0-rmse:0.41469	validation_1-rmse:0.49274
# [428]	validation_0-rmse:0.41461	validation_1-rmse:0.49273
# [429]	validation_0-rmse:0.41440	validation_1-rmse:0.49261
# [430]	validation_0-rmse:0.41425	validation_1-rmse:0.49267
# [431]	validation_0-rmse:0.41386	validation_1-rmse:0.49238
# [432]	validation_0-rmse:0.41376	validation_1-rmse:0.49238
# [433]	validation_0-rmse:0.41370	validation_1-rmse:0.49240
# [434]	validation_0-rmse:0.41337	validation_1-rmse:0.49222
# [435]	validation_0-rmse:0.41326	validation_1-rmse:0.49228
# [436]	validation_0-rmse:0.41305	validation_1-rmse:0.49219
# [437]	validation_0-rmse:0.41291	validation_1-rmse:0.49221
# [438]	validation_0-rmse:0.41262	validation_1-rmse:0.49200
# [439]	validation_0-rmse:0.41236	validation_1-rmse:0.49177
# [440]	validation_0-rmse:0.41216	validation_1-rmse:0.49156
# [441]	validation_0-rmse:0.41200	validation_1-rmse:0.49154
# [442]	validation_0-rmse:0.41192	validation_1-rmse:0.49156
# [443]	validation_0-rmse:0.41187	validation_1-rmse:0.49151
# [444]	validation_0-rmse:0.41171	validation_1-rmse:0.49144
# [445]	validation_0-rmse:0.41156	validation_1-rmse:0.49135
# [446]	validation_0-rmse:0.41138	validation_1-rmse:0.49129
# [447]	validation_0-rmse:0.41126	validation_1-rmse:0.49124
# [448]	validation_0-rmse:0.41109	validation_1-rmse:0.49121
# [449]	validation_0-rmse:0.41096	validation_1-rmse:0.49124
# [450]	validation_0-rmse:0.41088	validation_1-rmse:0.49128
# [451]	validation_0-rmse:0.41080	validation_1-rmse:0.49127
# [452]	validation_0-rmse:0.41066	validation_1-rmse:0.49120
# [453]	validation_0-rmse:0.41054	validation_1-rmse:0.49121
# [454]	validation_0-rmse:0.41042	validation_1-rmse:0.49122
# [455]	validation_0-rmse:0.41032	validation_1-rmse:0.49113
# [456]	validation_0-rmse:0.41022	validation_1-rmse:0.49103
# [457]	validation_0-rmse:0.41008	validation_1-rmse:0.49115
# [458]	validation_0-rmse:0.40992	validation_1-rmse:0.49095
# [459]	validation_0-rmse:0.40975	validation_1-rmse:0.49091
# [460]	validation_0-rmse:0.40966	validation_1-rmse:0.49085
# [461]	validation_0-rmse:0.40951	validation_1-rmse:0.49087
# [462]	validation_0-rmse:0.40930	validation_1-rmse:0.49076
# [463]	validation_0-rmse:0.40917	validation_1-rmse:0.49075
# [464]	validation_0-rmse:0.40900	validation_1-rmse:0.49068
# [465]	validation_0-rmse:0.40890	validation_1-rmse:0.49073
# [466]	validation_0-rmse:0.40869	validation_1-rmse:0.49048
# [467]	validation_0-rmse:0.40858	validation_1-rmse:0.49047
# [468]	validation_0-rmse:0.40852	validation_1-rmse:0.49053
# [469]	validation_0-rmse:0.40846	validation_1-rmse:0.49052
# [470]	validation_0-rmse:0.40840	validation_1-rmse:0.49045
# [471]	validation_0-rmse:0.40814	validation_1-rmse:0.49035
# [472]	validation_0-rmse:0.40808	validation_1-rmse:0.49037
# [473]	validation_0-rmse:0.40771	validation_1-rmse:0.49032
# [474]	validation_0-rmse:0.40759	validation_1-rmse:0.49032
# [475]	validation_0-rmse:0.40746	validation_1-rmse:0.49030
# [476]	validation_0-rmse:0.40734	validation_1-rmse:0.49027
# [477]	validation_0-rmse:0.40719	validation_1-rmse:0.49013
# [478]	validation_0-rmse:0.40706	validation_1-rmse:0.49011
# [479]	validation_0-rmse:0.40688	validation_1-rmse:0.48994
# [480]	validation_0-rmse:0.40674	validation_1-rmse:0.48987
# [481]	validation_0-rmse:0.40656	validation_1-rmse:0.48976
# [482]	validation_0-rmse:0.40641	validation_1-rmse:0.48969
# [483]	validation_0-rmse:0.40609	validation_1-rmse:0.48943
# [484]	validation_0-rmse:0.40585	validation_1-rmse:0.48955
# [485]	validation_0-rmse:0.40577	validation_1-rmse:0.48956
# [486]	validation_0-rmse:0.40555	validation_1-rmse:0.48949
# [487]	validation_0-rmse:0.40545	validation_1-rmse:0.48952
# [488]	validation_0-rmse:0.40524	validation_1-rmse:0.48959
# [489]	validation_0-rmse:0.40512	validation_1-rmse:0.48959
# [490]	validation_0-rmse:0.40506	validation_1-rmse:0.48960
# [491]	validation_0-rmse:0.40496	validation_1-rmse:0.48959
# [492]	validation_0-rmse:0.40485	validation_1-rmse:0.48952
# [493]	validation_0-rmse:0.40481	validation_1-rmse:0.48959
# [494]	validation_0-rmse:0.40470	validation_1-rmse:0.48960
# [495]	validation_0-rmse:0.40451	validation_1-rmse:0.48959
# [496]	validation_0-rmse:0.40433	validation_1-rmse:0.48945
# [497]	validation_0-rmse:0.40419	validation_1-rmse:0.48950
# [498]	validation_0-rmse:0.40408	validation_1-rmse:0.48943
# [499]	validation_0-rmse:0.40395	validation_1-rmse:0.48935
# [500]	validation_0-rmse:0.40365	validation_1-rmse:0.48908
# [501]	validation_0-rmse:0.40356	validation_1-rmse:0.48906
# [502]	validation_0-rmse:0.40339	validation_1-rmse:0.48894
# [503]	validation_0-rmse:0.40320	validation_1-rmse:0.48895
# [504]	validation_0-rmse:0.40309	validation_1-rmse:0.48894
# [505]	validation_0-rmse:0.40300	validation_1-rmse:0.48893
# [506]	validation_0-rmse:0.40296	validation_1-rmse:0.48898
# [507]	validation_0-rmse:0.40273	validation_1-rmse:0.48883
# [508]	validation_0-rmse:0.40258	validation_1-rmse:0.48879
# [509]	validation_0-rmse:0.40240	validation_1-rmse:0.48882
# [510]	validation_0-rmse:0.40231	validation_1-rmse:0.48890
# [511]	validation_0-rmse:0.40215	validation_1-rmse:0.48893
# [512]	validation_0-rmse:0.40204	validation_1-rmse:0.48889
# [513]	validation_0-rmse:0.40199	validation_1-rmse:0.48886
# [514]	validation_0-rmse:0.40187	validation_1-rmse:0.48888
# [515]	validation_0-rmse:0.40172	validation_1-rmse:0.48872
# [516]	validation_0-rmse:0.40161	validation_1-rmse:0.48864
# [517]	validation_0-rmse:0.40149	validation_1-rmse:0.48867
# [518]	validation_0-rmse:0.40134	validation_1-rmse:0.48861
# [519]	validation_0-rmse:0.40123	validation_1-rmse:0.48866
# [520]	validation_0-rmse:0.40103	validation_1-rmse:0.48854
# [521]	validation_0-rmse:0.40088	validation_1-rmse:0.48845
# [522]	validation_0-rmse:0.40069	validation_1-rmse:0.48843
# [523]	validation_0-rmse:0.40045	validation_1-rmse:0.48817
# [524]	validation_0-rmse:0.40037	validation_1-rmse:0.48816
# [525]	validation_0-rmse:0.40028	validation_1-rmse:0.48818
# [526]	validation_0-rmse:0.40006	validation_1-rmse:0.48796
# [527]	validation_0-rmse:0.39996	validation_1-rmse:0.48789
# [528]	validation_0-rmse:0.39990	validation_1-rmse:0.48789
# [529]	validation_0-rmse:0.39982	validation_1-rmse:0.48790
# [530]	validation_0-rmse:0.39968	validation_1-rmse:0.48775
# [531]	validation_0-rmse:0.39952	validation_1-rmse:0.48780
# [532]	validation_0-rmse:0.39934	validation_1-rmse:0.48781
# [533]	validation_0-rmse:0.39920	validation_1-rmse:0.48781
# [534]	validation_0-rmse:0.39903	validation_1-rmse:0.48783
# [535]	validation_0-rmse:0.39887	validation_1-rmse:0.48784
# [536]	validation_0-rmse:0.39875	validation_1-rmse:0.48777
# [537]	validation_0-rmse:0.39868	validation_1-rmse:0.48780
# [538]	validation_0-rmse:0.39865	validation_1-rmse:0.48782
# [539]	validation_0-rmse:0.39860	validation_1-rmse:0.48783
# [540]	validation_0-rmse:0.39848	validation_1-rmse:0.48790
# [541]	validation_0-rmse:0.39843	validation_1-rmse:0.48785
# [542]	validation_0-rmse:0.39827	validation_1-rmse:0.48767
# [543]	validation_0-rmse:0.39813	validation_1-rmse:0.48772
# [544]	validation_0-rmse:0.39800	validation_1-rmse:0.48769
# [545]	validation_0-rmse:0.39784	validation_1-rmse:0.48762
# [546]	validation_0-rmse:0.39774	validation_1-rmse:0.48757
# [547]	validation_0-rmse:0.39760	validation_1-rmse:0.48749
# [548]	validation_0-rmse:0.39745	validation_1-rmse:0.48743
# [549]	validation_0-rmse:0.39733	validation_1-rmse:0.48749
# [550]	validation_0-rmse:0.39721	validation_1-rmse:0.48736
# [551]	validation_0-rmse:0.39716	validation_1-rmse:0.48733
# [552]	validation_0-rmse:0.39713	validation_1-rmse:0.48746
# [553]	validation_0-rmse:0.39703	validation_1-rmse:0.48741
# [554]	validation_0-rmse:0.39692	validation_1-rmse:0.48733
# [555]	validation_0-rmse:0.39677	validation_1-rmse:0.48729
# [556]	validation_0-rmse:0.39660	validation_1-rmse:0.48722
# [557]	validation_0-rmse:0.39648	validation_1-rmse:0.48714
# [558]	validation_0-rmse:0.39641	validation_1-rmse:0.48713
# [559]	validation_0-rmse:0.39635	validation_1-rmse:0.48706
# [560]	validation_0-rmse:0.39619	validation_1-rmse:0.48697
# [561]	validation_0-rmse:0.39604	validation_1-rmse:0.48698
# [562]	validation_0-rmse:0.39571	validation_1-rmse:0.48670
# [563]	validation_0-rmse:0.39554	validation_1-rmse:0.48667
# [564]	validation_0-rmse:0.39543	validation_1-rmse:0.48660
# [565]	validation_0-rmse:0.39527	validation_1-rmse:0.48656
# [566]	validation_0-rmse:0.39514	validation_1-rmse:0.48661
# [567]	validation_0-rmse:0.39498	validation_1-rmse:0.48656
# [568]	validation_0-rmse:0.39482	validation_1-rmse:0.48652
# [569]	validation_0-rmse:0.39469	validation_1-rmse:0.48650
# [570]	validation_0-rmse:0.39457	validation_1-rmse:0.48642
# [571]	validation_0-rmse:0.39447	validation_1-rmse:0.48640
# [572]	validation_0-rmse:0.39442	validation_1-rmse:0.48638
# [573]	validation_0-rmse:0.39437	validation_1-rmse:0.48640
# [574]	validation_0-rmse:0.39426	validation_1-rmse:0.48627
# [575]	validation_0-rmse:0.39415	validation_1-rmse:0.48618
# [576]	validation_0-rmse:0.39389	validation_1-rmse:0.48614
# [577]	validation_0-rmse:0.39385	validation_1-rmse:0.48610
# [578]	validation_0-rmse:0.39368	validation_1-rmse:0.48600
# [579]	validation_0-rmse:0.39357	validation_1-rmse:0.48606
# [580]	validation_0-rmse:0.39348	validation_1-rmse:0.48605
# [581]	validation_0-rmse:0.39342	validation_1-rmse:0.48607
# [582]	validation_0-rmse:0.39328	validation_1-rmse:0.48605
# [583]	validation_0-rmse:0.39314	validation_1-rmse:0.48601
# [584]	validation_0-rmse:0.39299	validation_1-rmse:0.48597
# [585]	validation_0-rmse:0.39297	validation_1-rmse:0.48609
# [586]	validation_0-rmse:0.39280	validation_1-rmse:0.48608
# [587]	validation_0-rmse:0.39263	validation_1-rmse:0.48591
# [588]	validation_0-rmse:0.39232	validation_1-rmse:0.48568
# [589]	validation_0-rmse:0.39221	validation_1-rmse:0.48569
# [590]	validation_0-rmse:0.39209	validation_1-rmse:0.48567
# [591]	validation_0-rmse:0.39196	validation_1-rmse:0.48569
# [592]	validation_0-rmse:0.39183	validation_1-rmse:0.48572
# [593]	validation_0-rmse:0.39162	validation_1-rmse:0.48566
# [594]	validation_0-rmse:0.39150	validation_1-rmse:0.48564
# [595]	validation_0-rmse:0.39143	validation_1-rmse:0.48562
# [596]	validation_0-rmse:0.39137	validation_1-rmse:0.48560
# [597]	validation_0-rmse:0.39119	validation_1-rmse:0.48564
# [598]	validation_0-rmse:0.39116	validation_1-rmse:0.48562
# [599]	validation_0-rmse:0.39107	validation_1-rmse:0.48563
# [600]	validation_0-rmse:0.39098	validation_1-rmse:0.48559
# [601]	validation_0-rmse:0.39087	validation_1-rmse:0.48559
# [602]	validation_0-rmse:0.39079	validation_1-rmse:0.48560
# [603]	validation_0-rmse:0.39076	validation_1-rmse:0.48563
# [604]	validation_0-rmse:0.39065	validation_1-rmse:0.48562
# [605]	validation_0-rmse:0.39056	validation_1-rmse:0.48564
# [606]	validation_0-rmse:0.39046	validation_1-rmse:0.48553
# [607]	validation_0-rmse:0.39035	validation_1-rmse:0.48548
# [608]	validation_0-rmse:0.39025	validation_1-rmse:0.48542
# [609]	validation_0-rmse:0.39010	validation_1-rmse:0.48538
# [610]	validation_0-rmse:0.38998	validation_1-rmse:0.48540
# [611]	validation_0-rmse:0.38986	validation_1-rmse:0.48536
# [612]	validation_0-rmse:0.38973	validation_1-rmse:0.48542
# [613]	validation_0-rmse:0.38960	validation_1-rmse:0.48535
# [614]	validation_0-rmse:0.38953	validation_1-rmse:0.48536
# [615]	validation_0-rmse:0.38937	validation_1-rmse:0.48536
# [616]	validation_0-rmse:0.38918	validation_1-rmse:0.48522
# [617]	validation_0-rmse:0.38910	validation_1-rmse:0.48518
# [618]	validation_0-rmse:0.38896	validation_1-rmse:0.48513
# [619]	validation_0-rmse:0.38878	validation_1-rmse:0.48500
# [620]	validation_0-rmse:0.38869	validation_1-rmse:0.48500
# [621]	validation_0-rmse:0.38858	validation_1-rmse:0.48506
# [622]	validation_0-rmse:0.38842	validation_1-rmse:0.48490
# [623]	validation_0-rmse:0.38817	validation_1-rmse:0.48471
# [624]	validation_0-rmse:0.38804	validation_1-rmse:0.48464
# [625]	validation_0-rmse:0.38795	validation_1-rmse:0.48459
# [626]	validation_0-rmse:0.38783	validation_1-rmse:0.48462
# [627]	validation_0-rmse:0.38781	validation_1-rmse:0.48455
# [628]	validation_0-rmse:0.38767	validation_1-rmse:0.48460
# [629]	validation_0-rmse:0.38754	validation_1-rmse:0.48458
# [630]	validation_0-rmse:0.38741	validation_1-rmse:0.48457
# [631]	validation_0-rmse:0.38730	validation_1-rmse:0.48458
# [632]	validation_0-rmse:0.38725	validation_1-rmse:0.48458
# [633]	validation_0-rmse:0.38719	validation_1-rmse:0.48456
# [634]	validation_0-rmse:0.38706	validation_1-rmse:0.48457
# [635]	validation_0-rmse:0.38697	validation_1-rmse:0.48461
# [636]	validation_0-rmse:0.38689	validation_1-rmse:0.48464
# [637]	validation_0-rmse:0.38683	validation_1-rmse:0.48464
# [638]	validation_0-rmse:0.38670	validation_1-rmse:0.48460
# [639]	validation_0-rmse:0.38659	validation_1-rmse:0.48458
# [640]	validation_0-rmse:0.38647	validation_1-rmse:0.48469
# [641]	validation_0-rmse:0.38636	validation_1-rmse:0.48471
# [642]	validation_0-rmse:0.38629	validation_1-rmse:0.48471
# [643]	validation_0-rmse:0.38612	validation_1-rmse:0.48466
# [644]	validation_0-rmse:0.38597	validation_1-rmse:0.48448
# [645]	validation_0-rmse:0.38583	validation_1-rmse:0.48456
# [646]	validation_0-rmse:0.38571	validation_1-rmse:0.48454
# [647]	validation_0-rmse:0.38554	validation_1-rmse:0.48444
# [648]	validation_0-rmse:0.38546	validation_1-rmse:0.48439
# [649]	validation_0-rmse:0.38537	validation_1-rmse:0.48436
# [650]	validation_0-rmse:0.38528	validation_1-rmse:0.48435
# [651]	validation_0-rmse:0.38520	validation_1-rmse:0.48433
# [652]	validation_0-rmse:0.38505	validation_1-rmse:0.48438
# [653]	validation_0-rmse:0.38497	validation_1-rmse:0.48436
# [654]	validation_0-rmse:0.38489	validation_1-rmse:0.48432
# [655]	validation_0-rmse:0.38485	validation_1-rmse:0.48436
# [656]	validation_0-rmse:0.38481	validation_1-rmse:0.48439
# [657]	validation_0-rmse:0.38472	validation_1-rmse:0.48443
# [658]	validation_0-rmse:0.38462	validation_1-rmse:0.48440
# [659]	validation_0-rmse:0.38453	validation_1-rmse:0.48440
# [660]	validation_0-rmse:0.38435	validation_1-rmse:0.48420
# [661]	validation_0-rmse:0.38430	validation_1-rmse:0.48417
# [662]	validation_0-rmse:0.38419	validation_1-rmse:0.48412
# [663]	validation_0-rmse:0.38406	validation_1-rmse:0.48412
# [664]	validation_0-rmse:0.38396	validation_1-rmse:0.48413
# [665]	validation_0-rmse:0.38388	validation_1-rmse:0.48410
# [666]	validation_0-rmse:0.38372	validation_1-rmse:0.48414
# [667]	validation_0-rmse:0.38370	validation_1-rmse:0.48422
# [668]	validation_0-rmse:0.38356	validation_1-rmse:0.48431
# [669]	validation_0-rmse:0.38343	validation_1-rmse:0.48419
# [670]	validation_0-rmse:0.38333	validation_1-rmse:0.48412
# [671]	validation_0-rmse:0.38323	validation_1-rmse:0.48412
# [672]	validation_0-rmse:0.38319	validation_1-rmse:0.48407
# [673]	validation_0-rmse:0.38305	validation_1-rmse:0.48405
# [674]	validation_0-rmse:0.38298	validation_1-rmse:0.48407
# [675]	validation_0-rmse:0.38288	validation_1-rmse:0.48401
# [676]	validation_0-rmse:0.38275	validation_1-rmse:0.48398
# [677]	validation_0-rmse:0.38263	validation_1-rmse:0.48400
# [678]	validation_0-rmse:0.38248	validation_1-rmse:0.48390
# [679]	validation_0-rmse:0.38238	validation_1-rmse:0.48396
# [680]	validation_0-rmse:0.38231	validation_1-rmse:0.48395
# [681]	validation_0-rmse:0.38219	validation_1-rmse:0.48392
# [682]	validation_0-rmse:0.38209	validation_1-rmse:0.48394
# [683]	validation_0-rmse:0.38186	validation_1-rmse:0.48367
# [684]	validation_0-rmse:0.38180	validation_1-rmse:0.48365
# [685]	validation_0-rmse:0.38168	validation_1-rmse:0.48369
# [686]	validation_0-rmse:0.38131	validation_1-rmse:0.48343
# [687]	validation_0-rmse:0.38123	validation_1-rmse:0.48345
# [688]	validation_0-rmse:0.38114	validation_1-rmse:0.48338
# [689]	validation_0-rmse:0.38106	validation_1-rmse:0.48339
# [690]	validation_0-rmse:0.38098	validation_1-rmse:0.48343
# [691]	validation_0-rmse:0.38079	validation_1-rmse:0.48341
# [692]	validation_0-rmse:0.38060	validation_1-rmse:0.48331
# [693]	validation_0-rmse:0.38022	validation_1-rmse:0.48296
# [694]	validation_0-rmse:0.38010	validation_1-rmse:0.48296
# [695]	validation_0-rmse:0.38005	validation_1-rmse:0.48297
# [696]	validation_0-rmse:0.37993	validation_1-rmse:0.48305
# [697]	validation_0-rmse:0.37984	validation_1-rmse:0.48300
# [698]	validation_0-rmse:0.37963	validation_1-rmse:0.48286
# [699]	validation_0-rmse:0.37952	validation_1-rmse:0.48288
# [700]	validation_0-rmse:0.37942	validation_1-rmse:0.48289
# [701]	validation_0-rmse:0.37940	validation_1-rmse:0.48295
# [702]	validation_0-rmse:0.37928	validation_1-rmse:0.48294
# [703]	validation_0-rmse:0.37925	validation_1-rmse:0.48297
# [704]	validation_0-rmse:0.37912	validation_1-rmse:0.48302
# [705]	validation_0-rmse:0.37892	validation_1-rmse:0.48304
# [706]	validation_0-rmse:0.37886	validation_1-rmse:0.48299
# [707]	validation_0-rmse:0.37878	validation_1-rmse:0.48299
# [708]	validation_0-rmse:0.37862	validation_1-rmse:0.48290
# [709]	validation_0-rmse:0.37856	validation_1-rmse:0.48289
# [710]	validation_0-rmse:0.37847	validation_1-rmse:0.48291
# [711]	validation_0-rmse:0.37839	validation_1-rmse:0.48291
# [712]	validation_0-rmse:0.37837	validation_1-rmse:0.48292
# [713]	validation_0-rmse:0.37824	validation_1-rmse:0.48284
# [714]	validation_0-rmse:0.37822	validation_1-rmse:0.48285
# [715]	validation_0-rmse:0.37814	validation_1-rmse:0.48297
# [716]	validation_0-rmse:0.37807	validation_1-rmse:0.48289
# [717]	validation_0-rmse:0.37804	validation_1-rmse:0.48293
# [718]	validation_0-rmse:0.37795	validation_1-rmse:0.48296
# [719]	validation_0-rmse:0.37785	validation_1-rmse:0.48300
# [720]	validation_0-rmse:0.37783	validation_1-rmse:0.48304
# [721]	validation_0-rmse:0.37779	validation_1-rmse:0.48300
# [722]	validation_0-rmse:0.37771	validation_1-rmse:0.48294
# [723]	validation_0-rmse:0.37755	validation_1-rmse:0.48282
# [724]	validation_0-rmse:0.37745	validation_1-rmse:0.48273
# [725]	validation_0-rmse:0.37735	validation_1-rmse:0.48273
# [726]	validation_0-rmse:0.37727	validation_1-rmse:0.48275
# [727]	validation_0-rmse:0.37716	validation_1-rmse:0.48279
# [728]	validation_0-rmse:0.37704	validation_1-rmse:0.48274
# [729]	validation_0-rmse:0.37696	validation_1-rmse:0.48268
# [730]	validation_0-rmse:0.37683	validation_1-rmse:0.48260
# [731]	validation_0-rmse:0.37671	validation_1-rmse:0.48254
# [732]	validation_0-rmse:0.37666	validation_1-rmse:0.48248
# [733]	validation_0-rmse:0.37653	validation_1-rmse:0.48248
# [734]	validation_0-rmse:0.37641	validation_1-rmse:0.48245
# [735]	validation_0-rmse:0.37634	validation_1-rmse:0.48246
# [736]	validation_0-rmse:0.37624	validation_1-rmse:0.48247
# [737]	validation_0-rmse:0.37607	validation_1-rmse:0.48230
# [738]	validation_0-rmse:0.37594	validation_1-rmse:0.48230
# [739]	validation_0-rmse:0.37588	validation_1-rmse:0.48233
# [740]	validation_0-rmse:0.37582	validation_1-rmse:0.48229
# [741]	validation_0-rmse:0.37575	validation_1-rmse:0.48230
# [742]	validation_0-rmse:0.37562	validation_1-rmse:0.48220
# [743]	validation_0-rmse:0.37555	validation_1-rmse:0.48218
# [744]	validation_0-rmse:0.37546	validation_1-rmse:0.48215
# [745]	validation_0-rmse:0.37532	validation_1-rmse:0.48212
# [746]	validation_0-rmse:0.37529	validation_1-rmse:0.48218
# [747]	validation_0-rmse:0.37522	validation_1-rmse:0.48227
# [748]	validation_0-rmse:0.37515	validation_1-rmse:0.48226
# [749]	validation_0-rmse:0.37513	validation_1-rmse:0.48225
# [750]	validation_0-rmse:0.37508	validation_1-rmse:0.48231
# [751]	validation_0-rmse:0.37496	validation_1-rmse:0.48230
# [752]	validation_0-rmse:0.37488	validation_1-rmse:0.48231
# [753]	validation_0-rmse:0.37469	validation_1-rmse:0.48216
# [754]	validation_0-rmse:0.37460	validation_1-rmse:0.48213
# [755]	validation_0-rmse:0.37456	validation_1-rmse:0.48216
# [756]	validation_0-rmse:0.37453	validation_1-rmse:0.48218
# [757]	validation_0-rmse:0.37436	validation_1-rmse:0.48205
# [758]	validation_0-rmse:0.37426	validation_1-rmse:0.48206
# [759]	validation_0-rmse:0.37424	validation_1-rmse:0.48203
# [760]	validation_0-rmse:0.37406	validation_1-rmse:0.48201
# [761]	validation_0-rmse:0.37400	validation_1-rmse:0.48201
# [762]	validation_0-rmse:0.37385	validation_1-rmse:0.48203
# [763]	validation_0-rmse:0.37376	validation_1-rmse:0.48202
# [764]	validation_0-rmse:0.37360	validation_1-rmse:0.48201
# [765]	validation_0-rmse:0.37352	validation_1-rmse:0.48198
# [766]	validation_0-rmse:0.37345	validation_1-rmse:0.48195
# [767]	validation_0-rmse:0.37335	validation_1-rmse:0.48189
# [768]	validation_0-rmse:0.37328	validation_1-rmse:0.48194
# [769]	validation_0-rmse:0.37320	validation_1-rmse:0.48192
# [770]	validation_0-rmse:0.37317	validation_1-rmse:0.48191
# [771]	validation_0-rmse:0.37306	validation_1-rmse:0.48189
# [772]	validation_0-rmse:0.37302	validation_1-rmse:0.48188
# [773]	validation_0-rmse:0.37299	validation_1-rmse:0.48186
# [774]	validation_0-rmse:0.37290	validation_1-rmse:0.48191
# [775]	validation_0-rmse:0.37281	validation_1-rmse:0.48193
# [776]	validation_0-rmse:0.37271	validation_1-rmse:0.48196
# [777]	validation_0-rmse:0.37266	validation_1-rmse:0.48193
# [778]	validation_0-rmse:0.37258	validation_1-rmse:0.48192
# [779]	validation_0-rmse:0.37252	validation_1-rmse:0.48193
# [780]	validation_0-rmse:0.37251	validation_1-rmse:0.48192
# [781]	validation_0-rmse:0.37244	validation_1-rmse:0.48194
# [782]	validation_0-rmse:0.37232	validation_1-rmse:0.48189
# [783]	validation_0-rmse:0.37225	validation_1-rmse:0.48186
# [784]	validation_0-rmse:0.37213	validation_1-rmse:0.48193
# [785]	validation_0-rmse:0.37206	validation_1-rmse:0.48193
# [786]	validation_0-rmse:0.37203	validation_1-rmse:0.48197
# [787]	validation_0-rmse:0.37196	validation_1-rmse:0.48203
# [788]	validation_0-rmse:0.37190	validation_1-rmse:0.48200
# [789]	validation_0-rmse:0.37179	validation_1-rmse:0.48194
# [790]	validation_0-rmse:0.37176	validation_1-rmse:0.48198
# [791]	validation_0-rmse:0.37168	validation_1-rmse:0.48195
# [792]	validation_0-rmse:0.37152	validation_1-rmse:0.48191

# %% [markdown]
# Starting xgb benchmark: we've already improved on RF.

# %%
# predict using n_estimators with lowest validation error
rmse(gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit),y_test)
# Out:
# 0.48546188592549167

# %% [markdown]
# To tune, we should use validation results and ignore test until final verification. So here's the validation error benchmark we want to beat:

# %%
rmse(gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit),y_val)
# Out:
# 0.4818652619174388

# %% [markdown]
# ---
# **Xgboost Exercise**
#
# We'll approach tuning using this general framework, starting from the original parameters:
#
# 1. Tune max_depth
# 2. Tune subsample
# 3. Tune min_child_weight
# 4. Tune colsample_bytree
# 5. Set learning_rate to .05 and use early stopping to get n_estimators
#
# There are even more [xgboost parameters](https://github.com/dmlc/xgboost/blob/master/doc/parameter.md) such as regularization terms that are worth tuning, but this framework should be a starting point for solid parameters.
#
# For this process we'll repeat the cell block below with each adjustment and track our progress with comments, and tune in this way: say for max_depth, starting from 3 we try 5, 7 etc. until we stop improving then narrow down the search space.
#
# Start by _replacing the final parameters below_ with the basic parameters listed in the first run above, and see if you can recover parameters close to those referenced here.
#
# ---

# %%
#Step by step RMSEs, with .1 learning rate:
#best max_depth: 7, .452
#best subsample: .8, .448
#best min_child_weight: 12, .446
#best colsample_bytree: .7, .444

gbm = xgb.XGBRegressor(
    n_estimators=30000,  #arbitrary large number
    max_depth=7,
    objective="reg:squarederror",
    learning_rate=.05,
    subsample=.8,
    min_child_weight=8,
    colsample_bytree=.7,
    n_jobs=-1,
    random_state=0)

eval_set = [(X_train, y_train),
            (X_val, y_val)]  #tracking train/validation error as we go

fit_model = gbm.fit(
    X_train,
    y_train,
    eval_set=eval_set,
    eval_metric='rmse',
    early_stopping_rounds=50,
    verbose=False)

rmse(gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit), y_val)
# Out:
# 0.44481293179444903

# %% [markdown]
# And our test MSE as a result of this process, a ~10% reduction in RMSE from the random forest model:

# %%
rmse(gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit),y_test)
# Out:
# 0.4595623744492103

# %% [markdown]
# ---
#
# **Challenge**
#
# If you'd like to challenge yourself to get more proficient with xgboost, try tuning this model even more and beat our current score. Do some research into other xgboost parameters that you could try using. I'd recommend l1, l2, and gamma regularization terms.
#
# ---

# %% [markdown]
# **Interpretation**
#
# When trying to interpret a boosting model, we're faced with a similar challenge to that of interpreting a RF model. Many people would refer to it as a "black box" model. Luckily, there are some readily available ways to better understand feature importances and impacts on the model.
#
# The easiest method is very similar to RF feature importances. We can assign importance scores to features in a number of different ways, and xgboost lets us easily plot/extract these scores. The most common scoring methods are **frequency** (default, just calculates the # of total tree splits the feature is used in), and **gain** (probably better, calculates cumulative information gain from tree splits done on that feature).
#
# As we can see in the charts below, the two methods tend to agree on which features are most important. However, gain views Median Income as much more important than any of the other features, which seems like a reasonable conclusion.

# %%
xgb.plot_importance(gbm)
xgb.plot_importance(gbm, importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
gbm.get_booster().get_score(importance_type='weight') #extract raw frequency scores
# Out:
# {'MedInc': 6915,
#  'Latitude': 6777,
#  'Longitude': 6901,
#  'AveBedrms': 5875,
#  'HouseAge': 4038,
#  'AveRooms': 6255,
#  'Population': 5706,
#  'AveOccup': 6529}

# %%
gbm.get_booster().get_score(importance_type='gain') #extract raw gain scores
# Out:
# {'MedInc': 8.01005538083258,
#  'Latitude': 2.7667274916058617,
#  'Longitude': 2.8321389561374732,
#  'AveBedrms': 0.7740916085344146,
#  'HouseAge': 1.5760195979182194,
#  'AveRooms': 1.6407432813960818,
#  'Population': 0.5865925101404298,
#  'AveOccup': 2.660912024759634}

# %% [markdown]
# A key problem with importance scores is that they only tell us which features are most relevant, not what the directional impact of the feature is on the model/target. Techniques have been developed to visually study these impacts that include [Partial Dependence](http://scikit-learn.org/stable/auto_examples/ensemble/plot_partial_dependence.html) and [Individual Conditional Expectation](https://arxiv.org/pdf/1309.6392.pdf) plots, but these are beyond the scope of this lecture.

# %% [markdown]
# **Classification Example**
#
# Breast cancer dataset (binary classification). Boosting does not seem to work that well on this problem (unsuprising given a small sample size of <600). But this shows how we can apply xgboost to a classification problem by simply changing the objective and eval_metric parameters.

# %%
bc_dataset = load_breast_cancer()
X = pd.DataFrame(bc_dataset.data)
X.columns = bc_dataset.feature_names
y = bc_dataset.target

#Split data into 3: 60% train, 20% validation, 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2)

# %%
gbm = xgb.XGBClassifier( 
        n_estimators=30000,
        max_depth=4,
        objective='binary:logistic', #new objective
        use_label_encoder=False,
        learning_rate=.05, 
        subsample=.8,
        min_child_weight=3,
        colsample_bytree=.8)

eval_set=[(X_train,y_train),(X_val,y_val)]

fit_model = gbm.fit(
                X_train, y_train, 
                eval_set=eval_set,
                eval_metric='error', #new evaluation metric: classification error (could also use AUC, e.g.)
                early_stopping_rounds=50,
                verbose=False)

accuracy_score(y_test, gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit))
# Out:
# 0.9473684210526315

# %% [markdown]
# **[Read the Docs!](https://xgboost.readthedocs.io/en/latest/python/python_api.html)**
