# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pickle

# %%
c = [
    'itg_mean',
    'itg_stdev',
    'itg_kurtosis',
    'itg_skewness',
    'dm_snr_mean',
    'dm_snr_stdev',
    'dm_snr_kurtosis',
    'dm_snr_skew',
    'candidate_pulsar'
]

# %%
df = pd.read_csv('HTRU2/HTRU_2.csv', header = None, names = c)

# %%
df_train, df_test = train_test_split(df,
                                   test_size = 0.2,
                                   random_state = 25)

# %%
with open('pickles/df_train.pickle', 'wb') as to_write:
    pickle.dump(df_train, to_write)
    
with open('pickles/df_test.pickle', 'wb') as to_write:
    pickle.dump(df_test, to_write)

# %%
df_train.shape, df_test.shape
# Out:
# ((14318, 9), (3580, 9))

# %%
sns.histplot(data = df, x = 'candidate_pulsar');
plt.xticks([0, 1]);

# %%
df_train.loc[:, 'candidate_pulsar'] = df_train['candidate_pulsar'].astype('category')
df_train['candidate_pulsar'] = df_train['candidate_pulsar'].cat.as_ordered()

# %%
df_train.head()
# Out:
#          itg_mean  itg_stdev  itg_kurtosis  itg_skewness  dm_snr_mean  \
# 8919   121.578125  49.825886     -0.176219     -0.243690     5.056856
# 9252   118.500000  50.953103      0.550068     -0.198991   208.629599
# 9350   104.648438  49.429810      0.245270      0.276053     2.716555
# 2705   115.476562  47.045185      0.093706     -0.148988     1.621237
# 17364   94.000000  48.231052      0.474113      0.517439     1.377090
#
#        dm_snr_stdev  dm_snr_kurtosis  dm_snr_skew candidate_pulsar
# 8919      27.225586         6.192722    40.359547                0
# 9252      45.183858        -2.526430     6.203674                0
# 9350      17.162389         8.371686    84.046356                0
# 2705      16.158688        11.588370   146.012676                0
# 17364     11.165707        13.843322   254.838790                0

# %%
#for i in df_train.columns[:-1]:    
sns.pairplot(df_train);

# %%
sns.scatterplot(data = df_train, x = 'itg_kurtosis', y = 'candidate_pulsar')
# Out:
# <AxesSubplot:xlabel='itg_kurtosis', ylabel='candidate_pulsar'>
