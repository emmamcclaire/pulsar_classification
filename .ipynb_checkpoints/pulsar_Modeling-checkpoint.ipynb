# %%
import pandas as pd
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st
from sklearn.model_selection import train_test_split

# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

plt.rcParams['figure.figsize'] = (5, 3)
sns.set(context='notebook', style='whitegrid', font_scale=1.2)

# %%
def f(dataframe):
    df_dict = {'Train': 'pickles/df_train.pickle',
              'Test': 'pickles/df_test.pickle'}
    with open(df_dict[dataframe],'rb') as read_file:
        global df
        df = pickle.load(read_file)
    
    print('\n\t\tdf = selected dataframe\n\t\tshape = ', df.shape)
    global selection
    selection = dataframe

interact(f, dataframe = ['Train', 'Test']);
# Out:
# interactive(children=(Dropdown(description='dataframe', options=('Train', 'Test'), value='Train'), Output()), …

# %%
# convert target variable to ordered categorical
df.loc[:, 'candidate_pulsar'] = df['candidate_pulsar'].astype('category')
df['candidate_pulsar'] = df['candidate_pulsar'].cat.as_ordered()

# %%
if selection == 'Train':
    df, df_val = train_test_split(df, test_size = 0.2, random_state = 25)
    print('df shape: ', df.shape, '\ndf_val shape: ', df_val.shape)
# Out:
# df shape:  (11454, 9)
# df_val shape:  (2864, 9)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Single Feature

# %% [markdown]
# ### Model 1
#
# ---
# ---
#
# feature = itg_kurtosis
# log reg parameters = default
#
# ---
#
# confusion matrix
#
# [[2577,    7],
# [  68,  212]]
#
# ROC AUC = 0.97

# %%
sns.scatterplot(data = df, x = 'itg_kurtosis', y = 'candidate_pulsar');

# %%
logr1 = LogisticRegression()

# %%
logr1.fit(df[['itg_kurtosis']], df['candidate_pulsar'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print('intercept: ', round(logr1.intercept_[0], 4))
print('itg_kurtosis coef: ', round(logr1.coef_[0][0], 4))
# Out:
# intercept:  -5.6136
# itg_kurtosis coef:  4.071

# %%
def create_eval_df(model, df, feature: list, target: str):
    df_eval = df.copy()
    df_eval['pred'] = model.predict(df[feature])
    df_eval['correct_pred'] = df_eval['pred'] == df_eval[target]
    df_eval['proba_pulsar'] = model.predict_proba(df_eval[feature])[:, 1]
    return df_eval

df_eval = create_eval_df(logr1, df_val, ['itg_kurtosis'], 'candidate_pulsar')

# %%
sns.scatterplot(data = df_eval, 
                x = 'itg_kurtosis',
                y = 'candidate_pulsar',
                hue = 'correct_pred'
               );

# %%
confusion_matrix(df_eval['candidate_pulsar'], df_eval['pred'])
# Out:
# array([[2577,    7],
#        [  68,  212]])

# %%
sns.scatterplot(data=df_eval,
                x='itg_kurtosis',
                y='proba_pulsar',
                hue='candidate_pulsar',
                marker='|',
                s=200);

# %%
fpr, tpr, thresholds = roc_curve(df_eval['candidate_pulsar'],
                                 df_eval['proba_pulsar'])

# %%
def plot_roc(true, probas):
    auc = roc_auc_score(true, probas)

    plt.plot(fpr, tpr, marker='o')
    plt.xlabel('1 - Specificity (FPR)')
    plt.ylabel('Sensitivity (TPR)');
    plt.title(f"Area Under the ROC Curve: {round(auc, 3)}");

# %%
plot_roc(df_eval['candidate_pulsar'], df_eval['proba_pulsar'])

# %% [markdown]
# ### Model 2
#
# ---
# ---
#
# feature → itg_kurtosis
# log reg parameters → solver = newton-cg
#
# ---
#
# confusion matrix
#
# [[2577,    7],
# [  68,  212]]
#
# ROC AUC = 0.97

# %%
logr2 = LogisticRegression(solver='newton-cg',  # For comparison, use the same solver as statsmodels default
                          C=100000)
logr2.fit(df[['itg_kurtosis']], df['candidate_pulsar'])
# Out:
# LogisticRegression(C=100000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df_eval2 = create_eval_df(logr2,
                          df_val,
                          ['itg_kurtosis'],
                          'candidate_pulsar')

# %%
confusion_matrix(df_eval2['candidate_pulsar'], df_eval2['pred'])
# Out:
# array([[2577,    7],
#        [  68,  212]])

# %%
plot_roc(df_eval2['candidate_pulsar'], df_eval2['proba_pulsar'])

# %% [markdown]
# ## Multiple Logistic Regression

# %% [markdown]
# ### Model 3
#
# ---
# ---
#
# features = itg_mean, itg_kurtosis
#
# ---

# %%
features = ['itg_mean', 'itg_kurtosis']

scaler = StandardScaler()
X_train = scaler.fit_transform(df[features])
y_train = df['candidate_pulsar']

# %%
logr3 = LogisticRegression(C = 10000)
logr3.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_val = scaler.transform(df_val[features])
preds = logr3.predict(X_val)

# %%
confusion_matrix(df_val['candidate_pulsar'],
                preds)
# Out:
# array([[2577,    7],
#        [  66,  214]])

# %%
plot_roc(df_val['candidate_pulsar'], logr3.predict_proba(X_val)[:, 1])

# %% [markdown]
# ### Model 4
#
# ---
# ---
#
# All features.
#
# ---
#
# **Confusion Matrix:**
#
# [[2574,   10],
#  [  52,  228]]
#
# **ROC AUC:**
#
# 0.976

# %%
df.columns[:-1]
# Out:
# Index(['itg_mean', 'itg_stdev', 'itg_kurtosis', 'itg_skewness', 'dm_snr_mean',
#        'dm_snr_stdev', 'dm_snr_kurtosis', 'dm_snr_skew'],
#       dtype='object')

# %%
scaler_all = StandardScaler()
X_train_all = scaler_all.fit_transform(df[df.columns[:-1]])
y_train = df['candidate_pulsar']

# %%
logr4 = LogisticRegression(C = 10000)
logr4.fit(X_train_all, y_train)
# Out:
# LogisticRegression(C=10000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_val_all = scaler_all.transform(df_val[df_val.columns[:-1]])
preds4 = logr4.predict(X_val_all)

# %%
X_val_all = scaler_all.transform(df_val[df_val.columns[:-1]])
preds4 = logr4.predict(X_val_all)

# %%
df_val.shape
# Out:
# (2864, 9)

# %%
confusion_matrix(df_val['candidate_pulsar'],
                preds4)
# Out:
# array([[2574,   10],
#        [  52,  228]])

# %%
plot_roc(df_val['candidate_pulsar'], logr4.predict_proba(X_val_all)[:, 1])

# %% [markdown]
# ### Model 5
#
# ---
# ---
#
# Add polynomial and interaction features to Model 4
#
# ---

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

poly = PolynomialFeatures(2)
X_poly = poly.fit_transform(X)

scaler = StandardScaler()
X_poly_sc = scaler.fit_transform(X_poly)

logr5 = LogisticRegression(C = 10000)
logr5.fit(X_poly_sc, y)
X_poly_sc.shape
# Out:
# /Users/emma-clairemccarthy/opt/anaconda3/envs/ids/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# (11454, 45)

# %%
X_val = df_val[df_val.columns[:-1]]
y_val = df_val[df_val.columns[-1]]
# Out:
# (2864, 8)

# %%
val_poly = scaler.transform(X_val)

val_poly_sc = poly.transform(val_poly)

preds5 = logr5.predict(val_poly_sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-229ceeea105e> in <module>
#       3 val_poly_sc = poly.transform(val_poly)
#       4
# ----> 5 preds5 = logr5.predict(val_poly_sc)
#
# ~/opt/anaconda3/envs/ids/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     291             Predicted class label per sample.
#     292         """
# --> 293         scores = self.decision_function(X)
#     294         if len(scores.shape) == 1:
#     295             indices = (scores > 0).astype(np.int)
#
# ~/opt/anaconda3/envs/ids/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     270         n_features = self.coef_.shape[1]
#     271         if X.shape[1] != n_features:
# --> 272             raise ValueError("X has %d features per sample; expecting %d"
#     273                              % (X.shape[1], n_features))
#     274
#
# ValueError: X has 45 features per sample; expecting 8

# %%
confusion_matrix(df_val['candidate_pulsar'],
                preds4)

# %% [markdown]
# # Gaussian Naive Bayes
#
# ---
# ---
#
# validation set score = 0.946
#
# ---

# %%
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
gnb = GaussianNB()
gnb.fit(X, y)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
gnb.score(df_val.iloc[:, :-1], df_val.iloc[:, -1])
# Out:
# 0.9455307262569832

# %%
gnb.theta_
# Out:
# array([[116.50698828,  47.34269085,   0.21045615,   0.38354185,
#           8.86805648,  23.21326426,   8.88734171, 114.30602712],
#        [ 56.52088356,  38.68094295,   3.11311102,  15.35101809,
#          50.1749846 ,  56.56168604,   2.72557168,  17.24349448]])

# %%
np.sqrt(gnb.sigma_)
# Out:
# array([[ 17.54721341,   6.22099451,   0.33798154,   1.03649617,
#          24.4807913 ,  16.6344317 ,   4.25733854, 108.4498163 ],
#        [ 29.03181905,   7.83878416,   1.8406879 ,  13.86068031,
#          45.8692786 ,  19.67380186,   3.03808143,  43.23130301]])

# %%
gnb.class_prior_
# Out:
# array([0.90946394, 0.09053606])

# %%
gnb.classes_
# Out:
# array([0, 1])

# %% [markdown]
# Do the predictions change when using the log probabilities?

# %%
log_preds = [list(x).index(max(list(x))) for x in gnb.predict_log_proba(df_val.iloc[:, :-1])]

# %%
match = [x == y for x, y in zip(log_preds, gnb.predict(df_val.iloc[:, :-1]))]

# %%
count = 0
for i in match:
    if i == False:
        count += 1 
print(count, 'class assignment differences between standard and log_proba.')
# Out:
# 0 class assignment differences between standard and log_proba.

# %% [markdown]
# # KNN

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
# merge df and df_val so cross validation can be used instead
cv_df = pd.concat([df, df_val])
cv_df.shape
# Out:
# (14318, 9)

# %%
cv_X = cv_df.iloc[:, :-1]
cv_y = cv_df.iloc[:, -1]

# %% [markdown]
# ## Model 1
#
# ---
# ---
#
# weights = uniform
#
# ---

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
scores = cross_val_score(knn, cv_X, cv_y, cv=10, scoring='accuracy')


print(scores)
print(scores.mean())
# Out:
# [0.97206704 0.97625698 0.97067039 0.97067039 0.96787709 0.97346369
#  0.9825419  0.97346369 0.96855346 0.96995108]
# 0.9725515715462484

# %%
k_range = list(range(1, 60))

k_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    mean_score = cross_val_score(knn, cv_X, cv_y, cv=10, scoring='accuracy').mean()
    k_scores.append(mean_score)
    
sns.lineplot(x = k_range, y = k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# ## Model 2
#
# ---
# ---
#
# weights = distance
#
# ---

# %%
k_range_d = list(range(1, 60))

k_scores_d = []

for k in k_range_d:
    knn = KNeighborsClassifier(n_neighbors = k, weights = 'distance')
    mean_score = cross_val_score(knn, cv_X, cv_y, cv=10, scoring='accuracy').mean()
    k_scores_d.append(mean_score)

# %%
plt.plot(k_range, k_scores, 'r-', k_range_d, k_scores_d, 'g-')
plt.legend(['uniform', 'distance'], title = 'weights parameter')
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
# overall, knn performs better using 'distance' for the weights parameter

# best k:

best_score = 0
best_k = 0

for k, score in zip(k_range_d, k_scores_d):
    if score > best_score:
        best_score = score
        best_k = k
        
print('best score:', round(best_score, 3))
print('best k:', best_k)
# Out:
# best score: 0.974
# best k: 15

# %%
# check other parameters for potential accuracy improvements

for dis_code, dis in zip([1, 2], ['manhattan dist', 'euclidian dist']):    
    for a in ['auto', 'ball_tree', 'kd_tree', 'brute']:
        knn = KNeighborsClassifier(n_neighbors = 15, weights = 'distance', algorithm = a, p = dis_code)
        mean_score = cross_val_score(knn, cv_X, cv_y, cv=10, scoring='accuracy').mean()

        print(dis, '|', a, '|', mean_score)
    print('-------')
# Out:
# manhattan dist | auto | 0.974227939597656
# manhattan dist | ball_tree | 0.974227939597656
# manhattan dist | kd_tree | 0.974227939597656
# manhattan dist | brute | 0.974227939597656
# -------
# euclidian dist | auto | 0.9737389175831256
# euclidian dist | ball_tree | 0.9737389175831256
# euclidian dist | kd_tree | 0.9737389175831256
# euclidian dist | brute | 0.9737389175831256
# -------
